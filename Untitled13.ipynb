# %% [markdown]
# <a href="https://colab.research.google.com/github/KaterynaSiniuta/DataMath/blob/main/Untitled13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow import keras
from keras import models
from keras import layers
from keras import utils
from sklearn.metrics import confusion_matrix
import seaborn as sns

# %% [markdown]
# Розв’язання задачі MNIST ансамблем нейромереж
#
# Підготовка даних
# MNIST – це набір рукописних цифр (28x28 пікселів, 10 класів). Завантажуємо та нормалізуємо дані.

# %%
import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical

# %%
# Загрузка даних

(x_train, y_train), (x_test, y_test) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
# Візуалізація прикладів зображень MNIST без підписів цифр
fig, axes = plt.subplots(2, 5, figsize=(12, 6))
fig.suptitle("Приклади зображень з MNIST", fontsize=16, fontweight="bold")

for ax, img in zip(axes.flat, x_train[:10]):  # Беремо перші 10 зображень
    ax.imshow(img, cmap="gray")
    ax.axis("off")

plt.subplots_adjust(wspace=0.1, hspace=0.1)  # Мінімальні відступи між зображеннями
plt.show()

# %%
# Нормализація (значення від 0 до 1)

x_train, x_test = x_train / 255.0, x_test / 255.0

# %%
# One-hot encoding

y_train = to_categorical(y_train, 10)

y_test = to_categorical(y_test, 10)

# %%
# Для LSTM преобразуем в последовательности

x_train_lstm = x_train.reshape(-1, 28, 28)

x_test_lstm = x_test.reshape(-1, 28, 28)

# %% [markdown]
# 2. Створюємо моделі
#
#
# MLP (повнозв’язна мережа)![image_123650291 (53).JPG](data:image/jpeg;base64,...)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Input

mlp = Sequential([
    Input(shape=(28, 28)),
    Flatten(),
    Dense(256, activation='relu'),
    Dense(128, activation='relu'),
    Dense(64, activation='relu'),
    Dense(10, activation='softmax')
])

mlp.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# CNN (улучшенная сверточная сеть)![image_123650291 (54).JPG](data:image/jpeg;base64,...)

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dropout, BatchNormalization, Flatten, Dense, Input, Reshape

cnn = Sequential([
    Input(shape=(28, 28)),
    Reshape((28, 28, 1)),  # Преобразование в 4D-тензор (для свертки)

    Conv2D(32, (3, 3), activation='relu'),
    BatchNormalization(),
    MaxPooling2D((2, 2)),
    Dropout(0.3),

    Conv2D(64, (3, 3), activation='relu'),
    BatchNormalization(),
    MaxPooling2D((2, 2)),
    Dropout(0.3),

    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(10, activation='softmax')
])

cnn.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# LSTM (рекуррентная сеть)![image_123650291 (55).JPG](data:image/jpeg;base64,...)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Input

lstm = Sequential([
    Input(shape=(28, 28)),
    LSTM(128, return_sequences=True),
    LSTM(64),
    Dense(32, activation='relu'),
    Dense(10, activation='softmax')
])

lstm.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# 3. Навчання моделей

# %%
mlp.fit(x_train, y_train, epochs=10, batch_size=128, validation_data=(x_test, y_test))

cnn.fit(x_train, y_train, epochs=10, batch_size=128, validation_data=(x_test, y_test))

lstm.fit(x_train_lstm, y_train, epochs=10, batch_size=128, validation_data=(x_test_lstm, y_test))
# Out:
# Epoch 1/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.8431 - loss: 0.5331 - val_accuracy: 0.9583 - val_loss: 0.1381
# Epoch 2/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.9672 - loss: 0.1115 - val_accuracy: 0.9737 - val_loss: 0.0830
# Epoch 3/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.9787 - loss: 0.0685 - val_accuracy: 0.9737 - val_loss: 0.0829
# Epoch 4/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9844 - loss: 0.0498 - val_accuracy: 0.9764 - val_loss: 0.0756
# Epoch 5/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.9889 - loss: 0.0351 - val_accuracy: 0.9768 - val_loss: 0.0806
# Epoch 6/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.9914 - loss: 0.0268 - val_accuracy: 0.9773 - val_loss: 0.0710
# Epoch 7/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.9922 - loss: 0.0224 - val_accuracy: 0.9770 - val_loss: 0.0837
# Epoch 8/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.9928 - loss: 0.0209 - val_accuracy: 0.9783 - val_loss: 0.0749
# Epoch 9/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.9945 - loss: 0.0161 - val_accuracy: 0.9793 - val_loss: 0.0840
# Epoch 10/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.9947 - loss: 0.0157 - val_accuracy: 0.9800 - val_loss: 0.0773
# Epoch 1/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 82s 168ms/step - accuracy: 0.7725 - loss: 0.7913 - val_accuracy: 0.9299 - val_loss: 0.2161
# Epoch 2/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 92s 191ms/step - accuracy: 0.9545 - loss: 0.1493 - val_accuracy: 0.9856 - val_loss: 0.0439
# Epoch 3/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 82s 174ms/step - accuracy: 0.9692 - loss: 0.1030 - val_accuracy: 0.9871 - val_loss: 0.0363
# Epoch 4/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 95s 202ms/step - accuracy: 0.9742 - loss: 0.0867 - val_accuracy: 0.9890 - val_loss: 0.0328
# Epoch 5/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 127s 171ms/step - accuracy: 0.9773 - loss: 0.0771 - val_accuracy: 0.9902 - val_loss: 0.0371
# Epoch 6/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 80s 167ms/step - accuracy: 0.9778 - loss: 0.0752 - val_accuracy: 0.9877 - val_loss: 0.0394
# Epoch 7/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 75s 161ms/step - accuracy: 0.9816 - loss: 0.0626 - val_accuracy: 0.9912 - val_loss: 0.0313
# Epoch 8/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 80s 156ms/step - accuracy: 0.9814 - loss: 0.0638 - val_accuracy: 0.9907 - val_loss: 0.0279
# Epoch 9/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 84s 160ms/step - accuracy: 0.9827 - loss: 0.0596 - val_accuracy: 0.9914 - val_loss: 0.0308
# Epoch 10/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 75s 159ms/step - accuracy: 0.9848 - loss: 0.0508 - val_accuracy: 0.9918 - val_loss: 0.0259
# Epoch 1/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 79s 161ms/step - accuracy: 0.6665 - loss: 1.0105 - val_accuracy: 0.9496 - val_loss: 0.1657
# Epoch 2/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 72s 139ms/step - accuracy: 0.9541 - loss: 0.1530 - val_accuracy: 0.9488 - val_loss: 0.1620
# Epoch 3/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 64s 137ms/step - accuracy: 0.9690 - loss: 0.1023 - val_accuracy: 0.9767 - val_loss: 0.0762
# Epoch 4/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 65s 138ms/step - accuracy: 0.9788 - loss: 0.0679 - val_accuracy: 0.9776 - val_loss: 0.0735
# Epoch 5/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 82s 138ms/step - accuracy: 0.9819 - loss: 0.0584 - val_accuracy: 0.9823 - val_loss: 0.0582
# Epoch 6/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 82s 137ms/step - accuracy: 0.9872 - loss: 0.0436 - val_accuracy: 0.9849 - val_loss: 0.0501
# Epoch 7/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 75s 159ms/step - accuracy: 0.9879 - loss: 0.0387 - val_accuracy: 0.9841 - val_loss: 0.0516
# Epoch 8/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 81s 156ms/step - accuracy: 0.9901 - loss: 0.0325 - val_accuracy: 0.9868 - val_loss: 0.0444
# Epoch 9/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 75s 142ms/step - accuracy: 0.9905 - loss: 0.0304 - val_accuracy: 0.9852 - val_loss: 0.0485
# Epoch 10/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 80s 137ms/step - accuracy: 0.9896 - loss: 0.0303 - val_accuracy: 0.9889 - val_loss: 0.0372

# %% [markdown]
# 4. Усереднення передбачень (Bagging)
#
# Навчені моделі видають ймовірності класів, тому усереднюємо їх передбачення:

# %%
mlp_preds = mlp.predict(x_test)
cnn_preds = cnn.predict(x_test)
lstm_preds = lstm.predict(x_test_lstm)

# Усереднюємо

ensemble_preds = (mlp_preds + cnn_preds + lstm_preds) / 3

# З вирогідностей у класи

final_predictions = np.argmax(ensemble_preds, axis=1)

# Оцінюємо точність ансамбля

from sklearn.metrics import accuracy_score
true_labels = np.argmax(y_test, axis=1)
accuracy = accuracy_score(true_labels, final_predictions)

print(f"Ансамблева точність (Bagging): {accuracy:.4f}")
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step
# Ансамблева точність (Bagging): 0.9930

# %% [markdown]
# Bagging (усереднення передбачень) вже підвищує точність за рахунок згладжування помилок моделей.
